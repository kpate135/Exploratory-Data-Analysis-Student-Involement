# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data_df = pd.read_csv("survey.csv")
data_df.head()
# Out:
#            Timestamp  What is your age? What gender do you identify as?  \
# 0  5/2/2022 12:50:41                 21                           Woman
# 1  5/2/2022 13:37:49                 20                             Man
# 2  5/2/2022 13:38:05                 19                             Man
# 3  5/2/2022 13:39:48                 20                             Man
# 4  5/2/2022 13:42:48                 21                             Man
#
#   What year are you?  What is your current standing GPA?  \
# 0             Junior                                 NaN
# 1          Sophomore                                 NaN
# 2          Sophomore                                 NaN
# 3             Junior                                 NaN
# 4             Junior                                 NaN
#
#    What is your approximate cumulative GPA as of Winter 2022?  \
# 0                                               3.43
# 1                                               3.81
# ...
